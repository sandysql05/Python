# %%
import logging
from config import *
import base64
import requests
from datetime import datetime, timedelta
from urllib.parse import urlencode
import pandas as pd
#import pysftp

now = datetime.now()

# %%
logging.basicConfig(
    level=logging.INFO,
    format="{asctime} {levelname:<8} {message}",
    style='{',
    filename=LogFileName,#'%slog' % __file__[:-2],
    filemode='a'
)

#try:
if 1==1:
        class SpotifyAPI(object):
            access_token = None
            access_token_expires = now
            access_token_did_expire = True
            client_id = None
            client_secret = None
            token_url = "https://accounts.spotify.com/api/token"

            def __init__(self, client_id, client_secret, *args, **kwargs):
                super().__init__(*args, **kwargs)
                self.client_id = client_id
                self.client_secret = client_secret

            def get_client_credentials(self):
                """
                Returns a base64 encoded string
                """
                client_id = self.client_id
                client_secret = self.client_secret
                if client_secret is None or client_id is None:
                    raise Exception("You must set client_id and client_secret")
                client_creds = f"{client_id}:{client_secret}"
                client_creds_b64 = base64.b64encode(client_creds.encode())
                return client_creds_b64.decode()

            def get_token_headers(self):
                client_creds_b64 = self.get_client_credentials()
                return {
                    "Authorization": f"Basic {client_creds_b64}"
                }

            @staticmethod
            def get_token_data():
                return {
                    "grant_type": "client_credentials"
                }

            def perform_auth(self):
                token_url = self.token_url
                token_data = self.get_token_data()
                token_headers = self.get_token_headers()
                r = requests.post(token_url, data=token_data, headers=token_headers)
                if r.status_code not in range(200, 299):
                    raise Exception("Could not authenticate client.")
                    # return False
                data = r.json()
                access_token = data['access_token']
                expires_in = data['expires_in']  # seconds
                expires = now + timedelta(seconds=expires_in)
                self.access_token = access_token
                self.access_token_expires = expires
                self.access_token_did_expire = expires < now
                return True

            def get_access_token(self):
                token = self.access_token
                expires = self.access_token_expires
                if expires < now:
                    self.perform_auth()
                    return self.get_access_token()
                elif token is None:
                    self.perform_auth()
                    return self.get_access_token()
                return token

            def get_resource_header(self):
                access_token = self.get_access_token()
                headers = {
                    "Authorization": f"Bearer {access_token}"
                }
                return headers

            def search(self, query, search_type='artist'):  # type
                headers = self.get_resource_header()
                endpoint = "https://api.spotify.com/v1/search"
                data = urlencode({"q": query, "type": search_type.lower()})
                lookup_url = f"{endpoint}?{data}"
                r = requests.get(lookup_url, headers=headers)  # .json()
                if r.status_code not in range(200, 299):
                    return {}
                return r.json()

            def get_resource(self, lookup_id, resource_type='artists', version='v1', target='related-artists'):
                endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}/{target}"
                headers = self.get_resource_header()
                r = requests.get(endpoint, headers=headers)
                if r.status_code not in range(200, 299):
                    return {}
                return r.json()

            def get_related_artist(self, _id):
                return self.get_resource(_id, resource_type='artists', target='related-artists')

            def get_artist(self, _id):
                return self.get_resource(_id, resource_type='artists', target='albums')



spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify1 = SpotifyAPI(client_id, client_secret)

# %%
print(spotify.get_access_token())
# Out:
# BQCjijzQyS7Vu0XOLHQI-ZiSgJ6qCA8zjeQI_MYflWw0IUndsF46Ouy_F3HwqMMosdjqgKqoLRYnjhaqRrs

# %%
print(spotify1.get_access_token())
# Out:
# BQAiNxyRE1-YWtWQht7ZCxFcsmPC5erCdNIB2rVCT79c-Hlm4EDxhn7HGHZUfLDApwPT3Ulu8tPnLNmJ1q4

# %%
if 1==1:
    def getRelatedArtist(artist_name, id):
        # id='4Awgi8rHD631aMJCXLf21D'   ###uncomment for testing
        related_artists = []
        related_artist_cnt = len(spotify.get_related_artist(id)['artists'])
        # print("related_artist_cnt",related_artist_cnt)
        rank = 0
        JSON_Data = spotify.get_related_artist(id)['artists']  # ('4Awgi8rHD631aMJCXLf21D')

        if related_artist_cnt > 0:
            for x in range(0, related_artist_cnt):
                rank = rank + 1
                genres_cnt = 0
                image_cnt = 0
                genres_cnt = len(JSON_Data[x]['genres'])
                image_cnt = len(JSON_Data[x]['images'])

                # derive metadata
                Artist_Name = artist_name
                RelatedArtist_Name = JSON_Data[x]['name']
                External_Urls_Spotify = JSON_Data[x]['external_urls']['spotify']
                Followers_Total = JSON_Data[x]['followers']['total']
                if genres_cnt > 0:
                    Genres_001 = JSON_Data[x]['genres'][0]
                else:
                    Genres_001 = ''

                if genres_cnt > 1:
                    Genres_002 = JSON_Data[x]['genres'][1]
                else:
                    Genres_002 = ''

                if genres_cnt > 2:
                    Genres_003 = JSON_Data[x]['genres'][2]
                else:
                    Genres_003 = ''

                if genres_cnt > 3:
                    Genres_004 = JSON_Data[x]['genres'][3]
                else:
                    Genres_004 = ''

                if genres_cnt > 4:
                    Genres_005 = JSON_Data[x]['genres'][4]
                else:
                    Genres_005 = ''

                ID = JSON_Data[x]['id']

                if image_cnt > 0:
                    Large_image = JSON_Data[x]['images'][0]['url']
                else:
                    Large_image = ''

                if image_cnt > 1:
                    Medium_image = JSON_Data[x]['images'][1]['url']
                else:
                    Medium_image = ''

                if image_cnt > 2:
                    Small_image = JSON_Data[x]['images'][2]['url']
                else:
                    Small_image = ''

                Popularity = JSON_Data[x]['popularity']
                Type = JSON_Data[x]['type']

                artist = [Artist_Name , RelatedArtist_Name, rank, External_Urls_Spotify , Followers_Total
                    , Genres_001, Genres_002, Genres_003, Genres_004, Genres_005
                    , ID
                    , Large_image
                    , Medium_image
                    , Small_image
                    , Popularity, Type]

                related_artists.append(artist)

        return related_artists

# %%
#read previously processed Artists and their ID's
master_artists_ids = pd.read_csv(r"C:\Users\sgondela\Documents\GitHub\Python\PythonSpotify\Python Spotify Extract - Resolve Timeout Issues\DataFiles\artists_ids_repo.csv", sep=",", error_bad_lines=False)#   #For testing , nrows=10

print(master_artists_ids)
# Out:
#          Artist_Name                      id
# 0                !!!  1mmehjf7eHA10uHMisZGJg
# 1               $eem  7dGJo4pcD2V6oG8kP0tJRR
# 2             *NSYNC  6Ff53KvcvAj5U7Z1vojB5o
# 3     10,000 Maniacs  0MBIKH9DjtBkv8O3nS6szj
# 4          11th Hour  1HtIwustFdmwPcgO3IuShY
# ...              ...                     ...
# 9923              태리  2bPplnV1NOXAUHNJj1J6Kp
# 9924             패티김  3YLoKDj5EXsg3AorXDgLlz
# 9925            布衣乐队  1mAvMCqbfvkiCMroH79c8I
# 9926  明太Rocker×あちこあこ  7a0KfKuka42fBmNcRWQNIw
# 9927             石丸寛  23WbZvnBPb20zjKCjEgDNY
#
# [9928 rows x 2 columns]

# %%
artists = pd.read_csv(SourceFileName, encoding='UTF-16', sep="|", error_bad_lines=False)#   #For testing , nrows=10


print(artists)
# Out:
#          Artist_Name  ID
# 0                !!! NaN
# 1               $eem NaN
# 2             *NSYNC NaN
# 3     10,000 Maniacs NaN
# 4          11th Hour NaN
# ...              ...  ..
# 9965              태리 NaN
# 9966             패티김 NaN
# 9967            布衣乐队 NaN
# 9968  明太Rocker×あちこあこ NaN
# 9969             石丸寛 NaN
#
# [9970 rows x 2 columns]
# b'Skipping line 4982: expected 2 fields, saw 3\nSkipping line 9351: expected 2 fields, saw 3\n'

# %%
df = pd.merge(artists, master_artists_ids, 
                   on='Artist_Name', 
                   how='left')


Missing_Artist_ids = df[df['id'].isnull()]

# %%
Missing_Artist_ids
# Out:
#                           Artist_Name  ID   id
# 106                       Adam Groden NaN  NaN
# 565                   Art Ascher Rose NaN  NaN
# 1526    Chapeleiro & Samantha Machado NaN  NaN
# 1649                  Chris Hall Jose NaN  NaN
# 1902                       CORY MORAN NaN  NaN
# 2046           Dana Henderson Blocker NaN  NaN
# 2127              Darryl Pompey Lonny NaN  NaN
# 2507                      Don Friesen NaN  NaN
# 2652                Dustin Newman Roy NaN  NaN
# 2890                     ERIC BLANTON NaN  NaN
# 2965            Estelle Thrift Phelps NaN  NaN
# 3190               Frauke Scheunemann NaN  NaN
# 3545                Grupo Misma Linea NaN  NaN
# 3871      Indiana Bible College Choir NaN  NaN
# 4330                     JESSICA MOOG NaN  NaN
# 4516                    JOHANNA HAYES NaN  NaN
# 4568                   JOHN HARTFIELD NaN  NaN
# 5216                 KIM FACCONE KIUE NaN  NaN
# 5227       Kimberly Heilig Livingston NaN  NaN
# 5296                    KRISTINE HOPE NaN  NaN
# 5481                     Lena Gorelik NaN  NaN
# 5996                   Marlène Duroux NaN  NaN
# 6059                      MARY WALDEN NaN  NaN
# 6285                 Michael Kapoulas NaN  NaN
# 6453              Misty Isreal Haynes NaN  NaN
# 6483  Momomeolatis Dentrotaro Easeoto NaN  NaN
# 6503     Moonsun Christophe Schweizer NaN  NaN
# 6539                      Mr. Galetic NaN  NaN
# 6784                   Nueva Primicia NaN  NaN
# 6949                    PATRICIA BOON NaN  NaN
# 7859               Samuel Jersak Trio NaN  NaN
# 7992                   Septima Escala NaN  NaN
# 8534                     Tammie Davis NaN  NaN
# 8538                 Tammy Tyler Chan NaN  NaN
# 8886          The Hundred Dollar Band NaN  NaN
# 9142                    The Upsetters NaN  NaN
# 9195                 Theodora Whittle NaN  NaN
# 9228                    Those 2 Girls NaN  NaN
# 9527                   Ulises Camacho NaN  NaN
# 9573                   Vanessa Bourne NaN  NaN
# 9816        William Franklin Saunders NaN  NaN
# 9958                              ZRG NaN  NaN

# %%
artist_names = Missing_Artist_ids[['Artist_Name']].drop_duplicates()
artist_names['FULL_NAME'] = artist_names['Artist_Name']
print(artist_names)


print("Starting the process to extract ArtistID's")

artist_list = []
# Out:
#                           Artist_Name                        FULL_NAME
# 106                       Adam Groden                      Adam Groden
# 565                   Art Ascher Rose                  Art Ascher Rose
# 1526    Chapeleiro & Samantha Machado    Chapeleiro & Samantha Machado
# 1649                  Chris Hall Jose                  Chris Hall Jose
# 1902                       CORY MORAN                       CORY MORAN
# 2046           Dana Henderson Blocker           Dana Henderson Blocker
# 2127              Darryl Pompey Lonny              Darryl Pompey Lonny
# 2507                      Don Friesen                      Don Friesen
# 2652                Dustin Newman Roy                Dustin Newman Roy
# 2890                     ERIC BLANTON                     ERIC BLANTON
# 2965            Estelle Thrift Phelps            Estelle Thrift Phelps
# 3190               Frauke Scheunemann               Frauke Scheunemann
# 3545                Grupo Misma Linea                Grupo Misma Linea
# 3871      Indiana Bible College Choir      Indiana Bible College Choir
# 4330                     JESSICA MOOG                     JESSICA MOOG
# 4516                    JOHANNA HAYES                    JOHANNA HAYES
# 4568                   JOHN HARTFIELD                   JOHN HARTFIELD
# 5216                 KIM FACCONE KIUE                 KIM FACCONE KIUE
# 5227       Kimberly Heilig Livingston       Kimberly Heilig Livingston
# 5296                    KRISTINE HOPE                    KRISTINE HOPE
# 5481                     Lena Gorelik                     Lena Gorelik
# 5996                   Marlène Duroux                   Marlène Duroux
# 6059                      MARY WALDEN                      MARY WALDEN
# 6285                 Michael Kapoulas                 Michael Kapoulas
# 6453              Misty Isreal Haynes              Misty Isreal Haynes
# 6483  Momomeolatis Dentrotaro Easeoto  Momomeolatis Dentrotaro Easeoto
# 6503     Moonsun Christophe Schweizer     Moonsun Christophe Schweizer
# 6539                      Mr. Galetic                      Mr. Galetic
# 6784                   Nueva Primicia                   Nueva Primicia
# 6949                    PATRICIA BOON                    PATRICIA BOON
# 7859               Samuel Jersak Trio               Samuel Jersak Trio
# 7992                   Septima Escala                   Septima Escala
# 8534                     Tammie Davis                     Tammie Davis
# 8538                 Tammy Tyler Chan                 Tammy Tyler Chan
# 8886          The Hundred Dollar Band          The Hundred Dollar Band
# 9142                    The Upsetters                    The Upsetters
# 9195                 Theodora Whittle                 Theodora Whittle
# 9228                    Those 2 Girls                    Those 2 Girls
# 9527                   Ulises Camacho                   Ulises Camacho
# 9573                   Vanessa Bourne                   Vanessa Bourne
# 9816        William Franklin Saunders        William Franklin Saunders
# 9958                              ZRG                              ZRG
# Starting the process to extract ArtistID's

# %%
for artist in artist_names['FULL_NAME']:
    spotify.search(artist, search_type='artist')['artists']['items']
    try:
        if not result:
            continue
        else:
            id_val = result[0]['id']
            artist_name = artist

            Artist = [artist_name, id_val]
            print(Artist)
            artist_list.append(Artist)
    except:
        pass
        print('no data')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-50f34526aa66> in <module>
#       1 for artist in artist_names['FULL_NAME']:
# ----> 2     spotify.search(artist, search_type='artist')['artists']['items']
#       3     try:
#       4         if not result:
#       5             continue
#
# KeyError: 'artists'

# %%
for artist in artist_names['FULL_NAME']:
    print(artist)
    
    result = spotify.search(artist, search_type='artist')['artists']['items']
    # print(result)
    try:
        if not result:
            continue
        else:
            id_val = result[0]['id']
            artist_name = artist

            Artist = [artist_name, id_val]
            print(Artist)
            artist_list.append(Artist)
    except:
        pass
        print('no data')
# Out:
# Adam Groden
# Art Ascher Rose
# Chapeleiro & Samantha Machado
# Chris Hall Jose
# CORY MORAN
# Dana Henderson Blocker
# Darryl Pompey Lonny
# Don Friesen
# Dustin Newman Roy
# ERIC BLANTON
# Estelle Thrift Phelps
# Frauke Scheunemann
# Grupo Misma Linea
# Indiana Bible College Choir
# JESSICA MOOG
# JOHANNA HAYES
# JOHN HARTFIELD
# KIM FACCONE KIUE
# Kimberly Heilig Livingston
# KRISTINE HOPE
# Lena Gorelik
# Marlène Duroux
# MARY WALDEN
# Michael Kapoulas
# Misty Isreal Haynes
# Momomeolatis Dentrotaro Easeoto
# Moonsun Christophe Schweizer
# Mr. Galetic
# Nueva Primicia
# PATRICIA BOON
# Samuel Jersak Trio
# Septima Escala
# Tammie Davis
# Tammy Tyler Chan
# The Hundred Dollar Band
# The Upsetters
# Theodora Whittle
# Those 2 Girls
# Ulises Camacho
# Vanessa Bourne
# William Franklin Saunders
# ZRG

# %%
df_artists_ids = pd.DataFrame(artist_list,
                    columns=['artist_name', 'id'])
LocalFileName = OutputFileName + '.csv'
FinalOutputFileName = OutputFileName + '_' + now.strftime('%Y-%m-%d') + '.csv'
df_artists_ids.to_csv('artists_ids_repo.csv', sep=',', index=False)

#print(artist_list)

Full_Related_Artists = []
print('Starting data load')

for i in range(len(artist_list)):
    # time.sleep(.5)
    try:
        Artists = getRelatedArtist(artist_list[i][0], artist_list[i][1])  # getRelatedArtist(related_artist[i])
        for Artist in Artists:
            Full_Related_Artists.append(Artist)
    except:
        pass
# create dataset
df = pd.DataFrame(Full_Related_Artists,
                    columns=['Artist_Name', 'RelatedArtist_Name', 'Rank', 'External_Urls_Spotify', 'Followers_Total'
                        , 'Genres_001', 'Genres_002', 'Genres_003', 'Genres_004', 'Genres_005'
                        , 'ID', 'Large_image', 'Medium_image', 'Small_image', 'Popularity', 'Type', ])
LocalFileName = OutputFileName + '.csv'
FinalOutputFileName = OutputFileName +'_'+ now.strftime('%Y-%m-%d') + '.csv'
df.to_csv(LocalFileName, sep=',', index = False)

print('Operation completed')
# with pysftp.Connection(host=myHostname, username=myUsername, password=myPassword) as sftp_upload:
#     print("Upload connection succesfully stablished ... \n")
if 1==1:
        

remotepath = r'/Import/Spotify/'+FinalOutputFileName
localpath = LocalFileName

# o_var = sftp_upload.put(localpath, remotepath, confirm=False)
# print('o_var:', o_var)
# sftp_upload.close()
print("File uploaded... \n")
# In[ ]:
exit(200)

except Exception as e1:
print('[Error-1]:', e1)
logging.ERROR("Error Exception Occured: ",exc_info=True)
logging.critical("Critical Exception Occured Error: ",exc_info=True)
logging.warning("Warning Exception Occured Error: ",exc_info=True)
