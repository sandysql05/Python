# %%
import base64

# %%
import requests
import datetime
from urllib.parse import urlencode

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.0.4)

# %%
client_id = 'dd67a453d722441da636647587d4a7be'
client_secret = '26cf26febfd24315aa047ef52566d669'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def get_client_credentials(self):
        """
        Returns a base64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        } 
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200, 299):
            raise Exception("Could not authenticate client.")
            # return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] # seconds
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token() 
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers

    def search(self, query, search_type='artist' ): # type
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        data = urlencode({"q": query, "type": search_type.lower()})
        lookup_url = f"{endpoint}?{data}"
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200, 299):  
            return {}
        return r.json()
    
    
    def get_resource(self, lookup_id, resource_type='artists', version='v1',target='related-artists'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}/{target}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    

    def get_related_artist(self, _id):
        return self.get_resource(_id, resource_type='artists',target='related-artists')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists',target='albums')

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.search("Devi Sri Prasad",search_type='artist')
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Devi+Sri+Prasad&type=artist&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#     'followers': {'href': None, 'total': 1654219},
#     'genres': ['deep indian pop',
#      'desi hip hop',
#      'filmi',
#      'modern bollywood',
#      'tollywood'],
#     'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#     'id': '5sSzCxHtgL82pYDvx2QyEU',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/5e9ba88e6ea6149039f39bfaef11cfd3a8cbd150',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/9896d4ceed2f5173cb958151897038aadf49bff8',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/64805bd6ebae5ebce389d1d06032c4d66d473e40',
#       'width': 160}],
#     'name': 'Devi Sri Prasad',
#     'popularity': 61,
#     'type': 'artist',
#     'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 1}}

# %%
spotify.get_related_artist('5sSzCxHtgL82pYDvx2QyEU')
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7puWXcCM8Li3HnKrxc1bEH'},
#    'followers': {'href': None, 'total': 319280},
#    'genres': ['deep indian pop', 'filmi', 'tollywood'],
#    'href': 'https://api.spotify.com/v1/artists/7puWXcCM8Li3HnKrxc1bEH',
#    'id': '7puWXcCM8Li3HnKrxc1bEH',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27368c87aa893669b5177ebc817',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0268c87aa893669b5177ebc817',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485168c87aa893669b5177ebc817',
#      'width': 64}],
#    'name': 'Chakri',
#    'popularity': 40,
#    'type': 'artist',
#    'uri': 'spotify:artist:7puWXcCM8Li3HnKrxc1bEH'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3AMxH9QIPZbK8ND8C9j4Ss'},
#    'followers': {'href': None, 'total': 896080},
#    'genres': ['deep indian pop', 'desi hip hop', 'filmi', 'tollywood'],
#    'href': 'https://api.spotify.com/v1/artists/3AMxH9QIPZbK8ND8C9j4Ss',
#    'id': '3AMxH9QIPZbK8ND8C9j4Ss',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27370784f05049ab5eabc916adb',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0270784f05049ab5eabc916adb',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485170784f05049ab5eabc916adb',
#      'width': 64}],
#    'name': 'Mani Sharma',
#    'popularity': 53,
#    'type': 'artist',
#    'uri': 'spotify:artist:3AMxH9QIPZbK8ND8C9j4Ss'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7zFlr6Y537SdALqy0Xfvth'},
#    'followers': {'href': None, 'total': 303948},
#    'genres': ['deep indian pop',
#     'desi hip hop',
#     'filmi',
#     'modern bollywood',
#     'mollywood',
#     'tamil pop',
#     'telugu worship'],
#    'href': 'https://api.spotify.com/v1/artists/7zFlr6Y537SdALqy0Xfvth',
#    'id': '7zFlr6Y537SdALqy0Xfvth',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273562694e0e1acdc4d8f6e3f06',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02562694e0e1acdc4d8f6e3f06',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851562694e0e1acdc4d8f6e3f06',
#      'width': 64}],
#    'name': 'Ranjith Govind',
#    'popularity': 57,
#    'type': 'artist',
#    'uri': 'spotify:artist:7zFlr6Y537SdALqy0Xfvth'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/00hL0oJD4pWef0kPYIaSTy'},
#    'followers': {'href': None, 'total': 197492},
#    'genres': ['deep indian pop', 'filmi', 'tollywood'],
#    'href': 'https://api.spotify.com/v1/artists/00hL0oJD4pWef0kPYIaSTy',
#    'id': '00hL0oJD4pWef0kPYIaSTy',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27363bb0966d393bd27859602ff',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0263bb0966d393bd27859602ff',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485163bb0966d393bd27859602ff',
#      'width': 64}],
#    'name': 'R. P. Patnaik',
#    'popularity': 42,
#    'type': 'artist',
#    'uri': 'spotify:artist:00hL0oJD4pWef0kPYIaSTy'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0LSPREIgGMZXCuKVel7LVD'},
#    'followers': {'href': None, 'total': 322510},
#    'genres': ['deep indian pop',
#     'desi hip hop',
#     'desi pop',
#     'filmi',
#     'modern bollywood',
#     'tamil pop',
#     'telugu worship'],
#    'href': 'https://api.spotify.com/v1/artists/0LSPREIgGMZXCuKVel7LVD',
#    'id': '0LSPREIgGMZXCuKVel7LVD',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ecf302fe43d0b4ff0d0e0f3a32a26c1c5d015925',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/d800de706a8ab68216c72cb6da72b858a2ba6a3b',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/4b23d33832faaa63c001a9ae725c758713398db6',
#      'width': 160}],
#    'name': 'Karthik',
#    'popularity': 64,
#    'type': 'artist',
#    'uri': 'spotify:artist:0LSPREIgGMZXCuKVel7LVD'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6CWBs7ul78QwnBrcOCwhf5'},
#    'followers': {'href': None, 'total': 196201},
#    'genres': ['deep indian pop', 'filmi', 'modern bollywood', 'tollywood'],
#    'href': 'https://api.spotify.com/v1/artists/6CWBs7ul78QwnBrcOCwhf5',
#    'id': '6CWBs7ul78QwnBrcOCwhf5',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b065230e21c0470e10cece32',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b065230e21c0470e10cece32',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b065230e21c0470e10cece32',
#      'width': 64}],
#    'name': 'Sagar',
#    'popularity': 51,
#    'type': 'artist',
#    'uri': 'spotify:artist:6CWBs7ul78QwnBrcOCwhf5'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/29aw5YCdIw2FEXYyAJZI8l'},
#    'followers': {'href': None, 'total': 1125384},
#    'genres': ['deep indian pop', 'desi hip hop', 'filmi', 'tamil pop'],
#    'href': 'https://api.spotify.com/v1/artists/29aw5YCdIw2FEXYyAJZI8l',
#    'id': '29aw5YCdIw2FEXYyAJZI8l',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273812bfb4e32feb448e527e8b1',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02812bfb4e32feb448e527e8b1',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851812bfb4e32feb448e527e8b1',
#      'width': 64}],
#    'name': 'Harris Jayaraj',
#    'popularity': 63,
#    'type': 'artist',
#    'uri': 'spotify:artist:29aw5YCdIw2FEXYyAJZI8l'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0WiZi3Q419nMpAQEqfBCbk'},
#    'followers': {'href': None, 'total': 328373},
#    'genres': ['deep indian pop'],
#    'href': 'https://api.spotify.com/v1/artists/0WiZi3Q419nMpAQEqfBCbk',
#    'id': '0WiZi3Q419nMpAQEqfBCbk',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/351899e8e9c27b2396aac806db18f043907f6cfe',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/fc9762a4b773b4027f3227af26e87548b27ec4ec',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ca34d8cb3d7fbb6948430ad473a72d82ebdc60bd',
#      'width': 160}],
#    'name': 'Mickey J. Meyer',
#    'popularity': 46,
#    'type': 'artist',
#    'uri': 'spotify:artist:0WiZi3Q419nMpAQEqfBCbk'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0PykiHCcDsMPRV7s67qZ1B'},
#    'followers': {'href': None, 'total': 137555},
#    'genres': ['deep indian pop', 'desi hip hop', 'filmi', 'tamil pop'],
#    'href': 'https://api.spotify.com/v1/artists/0PykiHCcDsMPRV7s67qZ1B',
#    'id': '0PykiHCcDsMPRV7s67qZ1B',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c3304c86c273d8b14e1fbee5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c3304c86c273d8b14e1fbee5',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c3304c86c273d8b14e1fbee5',
#      'width': 64}],
#    'name': 'Tippu',
#    'popularity': 56,
#    'type': 'artist',
#    'uri': 'spotify:artist:0PykiHCcDsMPRV7s67qZ1B'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4TkLTkst9LQlJ0zAmXtXmv'},
#    'followers': {'href': None, 'total': 185902},
#    'genres': ['deep indian pop', 'tollywood'],
#    'href': 'https://api.spotify.com/v1/artists/4TkLTkst9LQlJ0zAmXtXmv',
#    'id': '4TkLTkst9LQlJ0zAmXtXmv',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273887caff5008a7f93a6d3e117',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02887caff5008a7f93a6d3e117',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851887caff5008a7f93a6d3e117',
#      'width': 64}],
#    'name': 'Ramana Gogula',
#    'popularity': 38,
#    'type': 'artist',
#    'uri': 'spotify:artist:4TkLTkst9LQlJ0zAmXtXmv'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5a2WF7juQ5oilpZCqikRtP'},
#    'followers': {'href': None, 'total': 148080},
#    'genres': ['deep indian pop', 'filmi', 'tollywood'],
#    'href': 'https://api.spotify.com/v1/artists/5a2WF7juQ5oilpZCqikRtP',
#    'id': '5a2WF7juQ5oilpZCqikRtP',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/a12645bb1fd7b9199c107f8f76965d1f27201292',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/8cbcff013942611b496376aef7e8bf26f8457062',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/f73a9cd1bc15e339e64c8874af2cdc9628abb5e1',
#      'width': 160}],
#    'name': 'Rahul Nambiar',
#    'popularity': 51,
#    'type': 'artist',
#    'uri': 'spotify:artist:5a2WF7juQ5oilpZCqikRtP'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2LMljlTXjGr7jPZOBmK9My'},
#    'followers': {'href': None, 'total': 92351},
#    'genres': ['deep indian pop', 'filmi', 'tamil pop'],
#    'href': 'https://api.spotify.com/v1/artists/2LMljlTXjGr7jPZOBmK9My',
#    'id': '2LMljlTXjGr7jPZOBmK9My',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27379aafea7e67ee1ce6bad8cca',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0279aafea7e67ee1ce6bad8cca',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485179aafea7e67ee1ce6bad8cca',
#      'width': 64}],
#    'name': 'S.A. Rajkumar',
#    'popularity': 38,
#    'type': 'artist',
#    'uri': 'spotify:artist:2LMljlTXjGr7jPZOBmK9My'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/27UbUuYAM8Hc1BZKlydOB0'},
#    'followers': {'href': None, 'total': 108124},
#    'genres': ['deep indian pop', 'tollywood'],
#    'href': 'https://api.spotify.com/v1/artists/27UbUuYAM8Hc1BZKlydOB0',
#    'id': '27UbUuYAM8Hc1BZKlydOB0',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273165f48ccce8306d12287b404',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02165f48ccce8306d12287b404',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851165f48ccce8306d12287b404',
#      'width': 64}],
#    'name': 'Raghu Kunche',
#    'popularity': 45,
#    'type': 'artist',
#    'uri': 'spotify:artist:27UbUuYAM8Hc1BZKlydOB0'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/13M1OXRslYiaRoeaUx75uY'},
#    'followers': {'href': None, 'total': 108764},
#    'genres': ['deep indian pop',
#     'desi hip hop',
#     'filmi',
#     'tamil hip hop',
#     'tamil pop',
#     'tollywood'],
#    'href': 'https://api.spotify.com/v1/artists/13M1OXRslYiaRoeaUx75uY',
#    'id': '13M1OXRslYiaRoeaUx75uY',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273fcf73068deedaf57fe16156c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02fcf73068deedaf57fe16156c',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851fcf73068deedaf57fe16156c',
#      'width': 64}],
#    'name': 'Achu',
#    'popularity': 42,
#    'type': 'artist',
#    'uri': 'spotify:artist:13M1OXRslYiaRoeaUx75uY'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2FgHPfRprDaylrSRVf1UlN'},
#    'followers': {'href': None, 'total': 1154907},
#    'genres': ['deep indian pop',
#     'desi hip hop',
#     'filmi',
#     'modern bollywood',
#     'tollywood'],
#    'href': 'https://api.spotify.com/v1/artists/2FgHPfRprDaylrSRVf1UlN',
#    'id': '2FgHPfRprDaylrSRVf1UlN',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/4ac07160c18101b9041d908d05eb252d25ed1828',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/cfeb2f68f5fcf6f220f1b0506cc4c1e9a1f1298b',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/170c78b393474ae42707345fddee11cd18285341',
#      'width': 160}],
#    'name': 'Thaman S',
#    'popularity': 64,
#    'type': 'artist',
#    'uri': 'spotify:artist:2FgHPfRprDaylrSRVf1UlN'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5VVN3xZw1i2qihfITZlvCZ'},
#    'followers': {'href': None, 'total': 576088},
#    'genres': ['deep indian pop', 'desi hip hop', 'filmi', 'tamil pop'],
#    'href': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ',
#    'id': '5VVN3xZw1i2qihfITZlvCZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/f70e5d4452362878b6188d25653c52eac0c38720',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/96f09a22e371db417cf39aafd925d63d679c5d03',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/45d9abe856dbaf87e9e830a048c544f535781ca7',
#      'width': 160}],
#    'name': 'G. V. Prakash',
#    'popularity': 65,
#    'type': 'artist',
#    'uri': 'spotify:artist:5VVN3xZw1i2qihfITZlvCZ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6AiX12wXdXFoGJ2vk8zBjy'},
#    'followers': {'href': None, 'total': 1465018},
#    'genres': ['deep indian pop', 'desi hip hop', 'filmi', 'tamil pop'],
#    'href': 'https://api.spotify.com/v1/artists/6AiX12wXdXFoGJ2vk8zBjy',
#    'id': '6AiX12wXdXFoGJ2vk8zBjy',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/d62f7538a08b56d482022d7faedf4bfbf085f117',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/19c3b07b96d56f2d7cc08258c7a7e7482e05a7bd',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/edf2e0eaccf41d4f9acc182821929e3a83986331',
#      'width': 160}],
#    'name': 'Yuvan Shankar Raja',
#    'popularity': 66,
#    'type': 'artist',
#    'uri': 'spotify:artist:6AiX12wXdXFoGJ2vk8zBjy'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7FaGCZiP3s6X7jQTB8EhfI'},
#    'followers': {'href': None, 'total': 174581},
#    'genres': ['deep indian pop', 'filmi', 'modern bollywood', 'tamil pop'],
#    'href': 'https://api.spotify.com/v1/artists/7FaGCZiP3s6X7jQTB8EhfI',
#    'id': '7FaGCZiP3s6X7jQTB8EhfI',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273707a6d31e1e7ceb65be7f9f3',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02707a6d31e1e7ceb65be7f9f3',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851707a6d31e1e7ceb65be7f9f3',
#      'width': 64}],
#    'name': 'Naresh Iyer',
#    'popularity': 59,
#    'type': 'artist',
#    'uri': 'spotify:artist:7FaGCZiP3s6X7jQTB8EhfI'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7aiZ7OX7ZWCtAFE0XLzR2n'},
#    'followers': {'href': None, 'total': 109676},
#    'genres': ['deep indian pop', 'filmi', 'tollywood'],
#    'href': 'https://api.spotify.com/v1/artists/7aiZ7OX7ZWCtAFE0XLzR2n',
#    'id': '7aiZ7OX7ZWCtAFE0XLzR2n',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f52df229bf91baae41a0ad0e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f52df229bf91baae41a0ad0e',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f52df229bf91baae41a0ad0e',
#      'width': 64}],
#    'name': 'Vedala Hemachandra',
#    'popularity': 50,
#    'type': 'artist',
#    'uri': 'spotify:artist:7aiZ7OX7ZWCtAFE0XLzR2n'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5TB837uKG65w8Jnz5D0bS5'},
#    'followers': {'href': None, 'total': 138919},
#    'genres': ['deep indian pop', 'desi hip hop', 'filmi', 'tamil pop'],
#    'href': 'https://api.spotify.com/v1/artists/5TB837uKG65w8Jnz5D0bS5',
#    'id': '5TB837uKG65w8Jnz5D0bS5',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734a0fc32c6b3815947fba667a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024a0fc32c6b3815947fba667a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514a0fc32c6b3815947fba667a',
#      'width': 64}],
#    'name': 'Vidyasagar',
#    'popularity': 47,
#    'type': 'artist',
#    'uri': 'spotify:artist:5TB837uKG65w8Jnz5D0bS5'}]}
